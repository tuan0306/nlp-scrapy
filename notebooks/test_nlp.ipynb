# %%
import sys
import json

sys.path.append('../')
from src.nlp_processor import NLPProcessor

# %%
# Đọc 5 bài đăng đầu tiên từ file clean_data.json
with open('../data/processed/clean_data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

nlp_processor=NLPProcessor('../assets/vietnamese-stopwords.txt')

# Thử nghiệm với bài đăng đầu tiên
bai_dang_1 = data[0]
mo_ta_goc = bai_dang_1['description_original']

print("--- MÔ TẢ GỐC ---")
print(mo_ta_goc[:500] + "...\n") # Chỉ in 500 ký tự cho đỡ rối

print("--- KẾT QUẢ SAU KHI QUA NLP ---")
print(nlp_processor.process_text(mo_ta_goc))
# Out:
# --- MÔ TẢ GỐC ---
# CHỈ CÒN 1 PHÒNG SIÊU ĐẸP (QUẬN 11) cách ngã 4 Âu Cơ & Lạc Long Quân 3p Địa chỉ 483/24 Lạc Long Quân, P.5, Q.11. DÀNH CHO NHỮNG BẠN TRẺ THÍCH TỰ DO & NHỮNG CẶP ĐÔI MUỐN CÓ CUỘC SỐNG RIÊNG TƯ + Cửa dùng thẻ từ hiện đại bảo vệ an ninh cho ban + Phòng không cửa sổ giúp bạn cảm giác kín đáo và ít vệ sinh + Máy lạnh. + Máy nước nóng. + WC riêng cho bạn cảm giác kín đáo. + Wifi tốc độ cao cho bạn lướt web như lướt sóng. Dịch vụ chuyên nghiệp: 1. Cho bạn chìa khóa riêng trao tay (không chung chủ), giờ g...
#
# --- KẾT QUẢ SAU KHI QUA NLP ---
# ...

# %%
bai_dang_2 = data[1]
mo_ta_goc = bai_dang_2['description_original']

print("--- MÔ TẢ GỐC ---")
print(mo_ta_goc[:500] + "...\n") # Chỉ in 500 ký tự cho đỡ rối

print("--- KẾT QUẢ SAU KHI QUA NLP ---")
print(nlp_processor.process_text(mo_ta_goc))
# Out:
# --- MÔ TẢ GỐC ---
# Cho thuê phòng có gác mới xây, có máy lạnh, Ngay Đình Phong Phú, gần Xa Lộ Hà Nội, Ngay Cao Đẳng Công Thương Địa chỉ: 190 Đình phong phú, tăng nhơn phú B, quận 9 ️Giá chỉ từ 3tr8 - 4tr Phòng mới xây, nội thất mới Máy lạnh , tủ quần áo Có nhà xe rộng, camera an ninh Cổng vân tay, giờ giấc tự do Call/Zalo: 0816229398 Gặp XNhi để được tư vấn xem phòng ạ Mình chuyên phòng trọ và căn hộ Thủ Đức, quận 9, quận 2 khách hàng có nhu cầu nhắn tin mình hỗ trợ ạ...
#
# --- KẾT QUẢ SAU KHI QUA NLP ---
# thuê phòng gác xây máy_lạnh đình phong_phú xa_lộ hà_nội cao_đẳng công_thương địa_chỉ 190 đình phong_phú nhơn_phú b 9 giá 3 tr8 4 tr phòng xây nội_thất máy_lạnh tủ quần_áo nhà_xe rộng camera an_ninh cổng vân giờ_giấc tự_do call zalo 0816229398 xnhi tư_vấn phòng chuyên phòng trọ căn_hộ thủ_đức 9 2 khách_hàng nhu_cầu nhắn_tin hỗ_trợ
